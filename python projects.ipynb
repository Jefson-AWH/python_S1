# %%
#sum of two numbers

x=int(input("enter first number:"))
y=int(input("enter second number:"))
print(x+y)
# Out:
# enter first number:10
# enter second number:100
# 110

# %%
#to print name,age,mark
name=input("enter your name:")
age=int(input("enter your age:"))
mark=float(input("enter your mark:"))
print(name,age,mark)
# Out:
# enter your name:keer
# enter your age:45
# enter your mark:34
# keer 45 34.0

# %%
#program to accept sides and finds its area
side=float(input("enter the length of the square:"))
area=side*side
print("the area of the square is:", area)
# Out:
# enter the length of the square:400
# the area of the square is: 160000.0

# %%
#program to accept base and height of right-angled triangle and find its area
base=float(input("enter the base value:"))
height=float(input("enter the height value"))
area=0.5*base*height
print("the area of the right-angled triangle is:",area)
# Out:
# enter the base value:10
# enter the height value20
# the area of the right-angled triangle is: 100.0

# %%
#program to accept principal amount, no of years,rate of interest and find simple interset
principal=float(input("enter the principal amount:"))
years=float(input("enter the  no of years: "))
rate=float(input("enter the rate of interest:"))
simple_interest=(principal*years*rate)/100
print("the simple interest rate is:",simple_interest)
# Out:
# enter the principal amount:1002
# enter the  no of years: 4
# enter the rate of interest:2
# the simple interest rate is: 80.16

# %%
#program to accept an integer and display the previous and next numbers
integer=int(input("enter an integer:"))
previous=integer-1
next_integer=integer+1
print("the previous integer is:",previous)
print("next integer is:",next_integer)
# Out:
# enter an integer:5
# the previous integer is: 4
# next integer is: 6

# %%
# sum,diffrence,product
x=float(input("enter the first number:"))
y=float(input("enter the second number:"))
sum_result= x+y
diffrence_result= x-y
product_result= x*y
print("sum:",sum_result)
print("diffrence:", diffrence_result)
print("product:", product_result)
# Out:
# enter the first number:5
# enter the second number:5
# sum: 10.0
# diffrence: 0.0
# product: 25.0

# %%
#quotient & remainder
x=float(input("enter the first number:"))
y=float(input("enter the second number:"))
quotient= x/y
remainder= x%y
print("quotient:", quotient)
print("remainder:", remainder)
# Out:
# enter the first number:5
# enter the second number:2
# quotient: 2.5
# remainder: 1.0

# %%
#enter radius and finds circles area
radius=float(input("enter the radius of the circle:"))
area= 3.14*radius*radius
print("area of the circle:", area)
# Out:
# enter the radius of the circle:20
# area of the circle: 1256.0

# %%
#check whether a number is greater than 100
num=int(input("enter a number:"))
if num <100:
    print("the entered number is less than 100")
else:
    print("entered number is greater than 100")
# Out:
# enter a number100
# entered number is greater than 100

# %%
#check whether a number is positive or negative
num=int(input("enter a number:"))
if num <0:
    print("the entered number is negative")
else:
    print("entered number is positive")
# Out:
# enter a number-4
# the entered number is negative

# %%
#check whether a number is even or odd
num=int(input("enter a number:"))
if num %2 == 0:
    print("the entered number is even")
else:
    print("entered number is odd")
# Out:
# enter a number5
# entered number is odd

# %%
#check two numbers are equal
x=int(input("enter the first number:"))
y=int(input("enter the second number:"))
if x == y:
    print("numbers are equal")
else:
    print("numbers are not equal")
# Out:
# enter the first number5
# enter the second number2
# numbers are not equal

# %%
#find the biggest of two numbers
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
if a>b:
    print("biggest number is:",a)
else:
    print("biggest number is:",b)
# Out:
# enter the first number:5
# enter the second number:10
# biggest number is: 10

# %%
#find if a preson is eligible to vote
age=int(input("enter your age:"))
if age<18:
    print("you are not eligible to vote")
else:
    print("you are eligible to vote")
# Out:
# enter your age:15
# you are not eligible to vote

# %%
#check if a number is divisible by 5
num=int(input("enter a number:"))
if num % 5==0:
    print(f"{num} is divisible by 5")
else:
    print(f"{num}is not divisible by 5")
# Out:
# enter a number:10
# 10 is divisible by 5

# %%
#check whether a number is positive , negative, zero
num=int(input("enter a number:"))
if num <0:
    print("the entered number is negative")
elif num ==0:
    print("entered number is zero")
else:
    print("entered number is positive")
# Out:
# enter a number:0
# entered number is zero

# %%
#find the biggest of three numbers
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
c=int(input("enter the third number:"))
if a > b:
    if a > c:
        print("Biggest number is:", a)
    else:
        print("Biggest number is:", c)
elif b > c:
    print("Biggest number is:", b)
else:
    print("Biggest number is:", c)
# Out:
# enter the first number:10
# enter the second number:200
# enter the third number:100
# Biggest number is: 200

# %%
#check divisibility of 7
num=int(input("enter the number:"))
if num % 7 == 0:
    print(f"{num} is divisible by 7")
else:
    print(f"{num} is not divisible by 7")
# Out:
# enter the number:371
# 371 is divisible by 7

# %%
#check if inputted character is vowel or not
char=input("enter a character:")
if (char == 'a' or char=='A' or char== 'e' or char=='E' or char=='i' or char=='I' or char=='o' or char=='O' or char=='u' or char=='U'):
    print("entered character is vowel")
else:
    print("entered character is not a vowel")
# Out:
# enter a character:O
# entered character is vowel

# %%
#check driving eligibility
age=int(input("enter age:"))
if age >= 18:
    print("you are eligible to apply driving licence")
else:
    print("you are not eligible to apply driving licence")
# Out:
# enter age:1
# you are not eligible to apply driving licence

# %%
#compare two string
s1=input("enter first string to compare:")
s2=input("enter second string to compare:")
if s1 == s2:
    print("entered string are same")
else:
    print("entered string not same")
# Out:
# enter first string to compare:gk
# enter second string to compare:kg
# entered string not same

# %%
#check discount eligibility
discount=int(input("enter the purchase amount to check discount eligibility:"))
if discount > 5000:
    print("you are eligible for a discount")
else:
    print("you are not eligible for discount")
# Out:
# enter the purchase amount to check discount eligibility:5001
# you are eligible for a discount

# %%
#check number range
num=int(input("enter a number:"))
if num > 10 or num < 100:
    print(f"{num}  lies between 10 and 100 ")
else:
    print(f"{num} does not lie between 10 and 100")
# Out:
# enter a number:99
# 99  lies between 10 and 100

# %%
#check exam eligibility
attendance=float(input("enter your attendance percentage:"))
if attendance >= 75:
    print("you are eligible to write exam")
else:
    print("you are not eligible to write exam")
# Out:
# enter your attendance percentage:75.6
# you are eligible to write exam

# %%
#check alphabet case
alphabet=input("enter a alphabet:")
if alphabet.isupper():
    print(f"{alphabet} is uppercase letter")
else:
    print(f"{alphabet} is lowercase letter")
# Out:
# enter a alphabet:Z
# Z is uppercase letter

# %%
#read three-digit number
num=int(input("enter number:"))
if num >=100 <=999:
    print(f"{num} is a three-digit number")
else:
    print(f"{num} is not a three-digit number")
# Out:
# enter number:968
# 968 is a three-digit number

# %%
#mobile data usage
d=float(input("enter the amount of mobile data used in GB:"))
if d < 2:
    print("low usage")
elif d >= 2 and d <= 5 :
    print("moderate usage")
else:
    print("high usage")
# Out:
# enter the amount of mobile data used in GB:1
# low usage

# %%
#create a lsit and display 
mark= [10,20,50,80,99]
print(mark[0])
# Out:
# 10

# %%
#create list and use append
a=[1,5,3,5]
a.append(50)
print(a)
# Out:
# [1, 5, 3, 5, 50]

# %%
#create tuple of 5 numbers and display 3rd element
number=(9,8,7,6,5)
print(number[2])
# Out:
# 7

# %%
#create set containing duplicate value and observe output
a={10,20,30,10}
print(a)
# Out:
# {10, 20, 30}
